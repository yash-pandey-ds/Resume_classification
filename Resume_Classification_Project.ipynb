# %%
import pandas as pd

# Load the data from the CSV file
file_path = 'Raw_Resume.csv'
resume_data = pd.read_csv(file_path, encoding='utf-8')

# Display the first few rows of the dataframe to understand its structure
print(resume_data.head())
print(resume_data.info())
# Out:
#                                               Resume        Type
# 0  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  PeopleSoft
# 1  G. Ananda Rayudu \n\n\t\t       https://www.li...  PeopleSoft
# 2  PeopleSoft Database Administrator\n\n         ...  PeopleSoft
# 3  Classification: Internal\n\nClassification: In...  PeopleSoft
# 4  Priyanka Ramadoss\n\n\t61/46, MountPleasant, \...  PeopleSoft
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Resume  78 non-null     object
#  1   Type    78 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB
# None

# %% [markdown]
# # **EDA**

# %%
resume_data['Type'].value_counts()
# Out:
# Type
# React Developer    24
# Workday            21
# PeopleSoft         19
# SQL Developer      14
# Name: count, dtype: int64

# %%
print(resume_data['Resume'])
# Out:
# 0     Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 1     G. Ananda Rayudu \n\n\t\t       https://www.li...
# 2     PeopleSoft Database Administrator\n\n         ...
# 3     Classification: Internal\n\nClassification: In...
# 4     Priyanka Ramadoss\n\n\t61/46, MountPleasant, \...
#                             ...
# 73    Workday Integration Consultant\n\n\n\nName    ...
# 74    Srikanth (WORKDAY hCM Consultant)\t           ...
# 75    WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 76    Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...
# 77    Vinay kumar .v\nWorkday Functional Consultant\...
# Name: Resume, Length: 78, dtype: object

# %% [markdown]
# ### **REMOVING DOB**

# %%
import re
def remove_dob(text):
  """
  Removes date of birth patterns from a given text.
  """
  # Define a regular expression pattern to match common date of birth formats
  pattern = r"(\d{1,2}/\d{1,2}/\d{4})|(\d{1,2}-\d{1,2}-\d{4})|(\d{4}-\d{1,2}-\d{1,2})"
  return re.sub(pattern, "", text)

# Apply the function to the 'Resume' column
resume_data['Resume'] = resume_data['Resume'].apply(remove_dob)

# %% [markdown]
# ### **TEXT CLEANING**

# %%
import re

def clean_resume(text):
    #Lower case
    text = text.lower()
    # Remove extra spaces and newlines
    text = re.sub(r'\s+', ' ', text)
    # Remove special characters
    text = re.sub(r'[^\w\s]', '', text)
    return text.strip()

# Apply the cleaning function to the 'Resume' column
resume_data['Resume'] = resume_data['Resume'].apply(clean_resume)

# Display the first few rows of the cleaned data
print(resume_data.head())
# Out:
#                                               Resume        Type
# 0  anubhav kumar singh core competencies scriptin...  PeopleSoft
# 1  g ananda rayudu httpswwwlinkedincominanandguda...  PeopleSoft
# 2  peoplesoft database administrator gangareddy p...  PeopleSoft
# 3  classification internal classification interna...  PeopleSoft
# 4  priyanka ramadoss 6146 mountpleasant coonoor t...  PeopleSoft

# %% [markdown]
# * The re module is Python's built-in library for working with regular expressions. It allows you to search, match, and manipulate strings based on patterns.
#
# * Remove extra spaces and newlines: The function first uses re.sub(r'\s+', ' ', text) to replace all sequences of whitespace characters (including spaces, tabs, and newlines) with a single space.
# * Remove special characters: The second re.sub call, re.sub(r'[^\w\s]', '', text), removes any character that is not a word character (alphanumeric) or whitespace. This effectively strips out punctuation and other special characters.
# * Trim the text: Finally, text.strip() removes any leading or trailing whitespace from the cleaned text.

# %%
import nltk
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Yash\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
resume_data["Resume"] = resume_data["Resume"].apply(lambda x: " ".join([lemmatizer.lemmatize(word) for  word in x.split()]))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Analyze the distribution of resume types
plt.figure(figsize=(10, 6))
sns.countplot(y='Type', data=resume_data, order=resume_data['Type'].value_counts().index)
plt.title('Distribution of Resume Types')
plt.xlabel('Count')
plt.ylabel('Resume Type')
plt.show()

# %%
resume_lengths = resume_data['Resume'].apply(len)
average_length = resume_lengths.mean()
print('Average Length of Resumes:', average_length)
# Out:
# Average Length of Resumes: 4854.833333333333

# %% [markdown]
# ### **STOPWORDS REMOVAL**

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# Function to remove stopwords from text
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in ENGLISH_STOP_WORDS]
    return ' '.join(filtered_words)

# Apply the stopword removal function to the 'Cleaned_Resume' column
resume_data['Resume'] = resume_data['Resume'].apply(remove_stopwords)

# %% [markdown]
# **EXPERIENCE AND USING ARE DISTURBING THE MOST FREQUENT WORD COUNT. THEY HAVE NO USE SO LET'S REMOVE THEM**

# %%
def remove_experience_using(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in ["experience", "using"]]
    return ' '.join(filtered_words)

# Apply the function to the 'Filtered_Resume' column
resume_data['Resume'] = resume_data['Resume'].apply(remove_experience_using)

# %% [markdown]
# ### **MOST FREQUENT WORDS**

# %%
from collections import Counter
# Find the most frequent words in each type of resume
resume_types = resume_data['Type'].unique()

# Dictionary to store the most common words for each resume type
most_common_words_by_type = {}

for resume_type in resume_types:
    # Filter resumes by type
    type_resumes = resume_data[resume_data['Type'] == resume_type]['Resume']
    # Join all resumes of this type into a single string
    all_words = ' '.join(type_resumes).split()
    # Count the frequency of each word
    word_counts = Counter(all_words)
    # Get the 10 most common words
    most_common_words = word_counts.most_common(10)
    # Store the result
    most_common_words_by_type[resume_type] = most_common_words

# Display the most common words for each resume type
for resume_type, words in most_common_words_by_type.items():
    print('Resume Type:', resume_type)
    for word, count in words:
        print(word, ':', count)
    print('\
')
# Out:
# Resume Type: PeopleSoft
# peoplesoft : 412
# server : 387
# application : 376
# database : 204
# process : 150
# environment : 140
# tool : 135
# people : 132
# project : 128
# domain : 121
#
# Resume Type: React Developer
# react : 116
# j : 101
# project : 94
# web : 74
# application : 72
# developer : 71
# technology : 69
# e : 67
# javascript : 64
# knowledge : 61
#
# Resume Type: SQL Developer
# sql : 188
# data : 122
# server : 106
# report : 79
# table : 75
# database : 72
# query : 62
# function : 61
# project : 56
# procedure : 44
#
# Resume Type: Workday
# workday : 428
# integration : 291
# report : 278
# business : 186
# eib : 137
# process : 125
# core : 113
# hcm : 112
# worked : 110
# connector : 109

# %% [markdown]
# **Experience word is present in each most frequent word list because it is a heading.It is not giving us any useful insight.**

# %% [markdown]
# ***Technical Skills: The resumes showcase a strong technical skillset, including proficiency in tools and technologies such as:***
#
# * **PeopleSoft-specific tools:** Application Designer, Data Mover, Integration Broker, Change Assistant, PeopleSoft Update Manager (PUM), SQR, PS Query, BI Publisher
# * **Databases:** Oracle, SQL Server, DB2
# * **Operating Systems:** Windows, Unix, Linux, HPUX
# * **Scripting and Programming:** Shell Scripting, PeopleCode, SQL

# %% [markdown]
# **PEOPLESOFT**

# %%
# Get the most common words for PeopleSoft resumes
peoplesoft_words = most_common_words_by_type['PeopleSoft']

# Extract words and counts
words = [word for word, count in peoplesoft_words]
counts = [count for word, count in peoplesoft_words]

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Most Frequent Words in PeopleSoft Resumes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **SQL DEVELOPER**

# %%
# Get the most common words for PeopleSoft resumes
sql_developer_words = most_common_words_by_type['SQL Developer']

# Extract words and counts
words = [word for word, count in sql_developer_words]
counts = [count for word, count in sql_developer_words]

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Most Frequent Words in SQL DEVELOPER Resumes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **REACT JS DEVELOPER**

# %%
# Get the most common words for PeopleSoft resumes
react_developer_words = most_common_words_by_type['React Developer']

# Extract words and counts
words = [word for word, count in react_developer_words]
counts = [count for word, count in react_developer_words]

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Most Frequent Words in React Developer Resumes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **WORKDAY**

# %%
# Get the most common words for PeopleSoft resumes
Workday_developer_words = most_common_words_by_type['Workday']

# Extract words and counts
words = [word for word, count in Workday_developer_words]
counts = [count for word, count in Workday_developer_words]

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Most Frequent Words in Workday Resumes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### **TOKENIZATION**

# %%
from nltk.corpus import stopwords
import nltk

# %%
import nltk

nltk.download('punkt') # Download the 'punkt' resource

nltk_tokens = nltk.word_tokenize('Resume')
print(list(nltk.bigrams(nltk_tokens)))
# Out:
# []
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Yash\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### **EXPERIENCE OF EACH RESUME TYPE**

# %%
React_resume = resume_data[resume_data['Type'] == 'React Developer']
SQL_resume = resume_data[resume_data['Type'] == 'SQL Developer']
Workday_resume = resume_data[resume_data['Type'] == 'Workday']
Peoplesoft_resume = resume_data[resume_data['Type'] == 'PeopleSoft']

# %% [markdown]
# ### **EXPERIENCE OF POEOPLESOFT**

# %%
#PEOPLESOFT
total_exp_People = []
single_exp = []
for j in range(len(Peoplesoft_resume.Resume)):
    nltk_tokens = nltk.word_tokenize(Peoplesoft_resume.Resume[j])
    bi_list = list(nltk.bigrams(nltk_tokens))
    single_exp = []
    for i in bi_list:
        if i[1].rstrip('s') == 'year':
#             print(i[0])
            single_exp.append(i[0])
    total_exp_People.append(single_exp)

#Iterate through the list and replace '+' with ''
for idx,l in enumerate(total_exp_People):
    for idy,val in enumerate(l):
        total_exp_People[idx][idy] = val.replace("+", "")

total_exp_People
# Out:
# [[],
#  ['7'],
#  ['4'],
#  ['6'],
#  ['411', 'boarduniversity'],
#  ['68'],
#  ['10', 'andhrapradesh'],
#  ['42', '42'],
#  [],
#  ['64', '44', '44'],
#  ['75', '75'],
#  ['04'],
#  ['41', 'cgpa', '2', '2', 'university'],
#  ['102'],
#  ['46'],
#  ['46'],
#  ['36'],
#  ['32'],
#  ['36']]

# %% [markdown]
# **The exp is not 411 its 4.11, lets convert them back to decimal form.**

# %%
# Iterate through the list and replace '+' with ''
for idx, l in enumerate(total_exp_People):
    for idy, val in enumerate(l):
        # Check if the value is a number and contains a '+'
        if val.isdigit() and '+' in val:
            # Replace '+' with ''
            total_exp_People[idx][idy] = val.replace("+", "")
        # Check if the value is a number and does not contain a decimal
        if val.isdigit() and '.' not in val:
            # Add a decimal after the first integer
            total_exp_People[idx][idy] = val[:1] + '.' + val[1:]

# %% [markdown]
# **now convert them back to float**

# %%
# Convert the experience values to float and handle non-convertible values
def convert_to_float(exp_list):
  """
  Converts a list of experience values to float and drops non-convertible values.
  """
  float_exp = []
  for exp in exp_list:
    try:
      float_exp.append(float(exp))
    except ValueError:
      pass  # Ignore non-convertible values
  return float_exp

# Apply the function to the experience list
total_exp_People = [convert_to_float(exp_list) for exp_list in total_exp_People]
total_exp_People
# Out:
# [[],
#  [7.0],
#  [4.0],
#  [6.0],
#  [4.11],
#  [6.8],
#  [1.0],
#  [4.2, 4.2],
#  [],
#  [6.4, 4.4, 4.4],
#  [7.5, 7.5],
#  [0.4],
#  [4.1, 2.0, 2.0],
#  [1.02],
#  [4.6],
#  [4.6],
#  [3.6],
#  [3.2],
#  [3.6]]

# %%
import numpy as np

# Flatten the list of lists
flat_list = [item for sublist in total_exp_People for item in sublist]

# Convert the strings to numbers
numeric_list = [float(x) for x in flat_list] # Changed int to float

# Calculate the average
if numeric_list:
  average_years = np.mean(numeric_list)
  print("Average years of experience:", average_years)
else:
  print("No numeric values found in the list.")
# Out:
# Average years of experience: 4.2013043478260865

# %% [markdown]
# ### **EXPERIENCE OF REACT**

# %%
#REACT
total_exp_react = []
single_exp = []
for j in range(len(React_resume.index)): # Use React_resume.index to iterate over the actual index values
    nltk_tokens = nltk.word_tokenize(React_resume.Resume[React_resume.index[j]])
    bi_list = list(nltk.bigrams(nltk_tokens))
    single_exp = []
    for i in bi_list:
        if i[1].rstrip('s') == 'year':
#             print(i[0])
            single_exp.append(i[0])
    total_exp_react.append(single_exp)

#Iterate through the list and replace '+' with ''
for idx,l in enumerate(total_exp_react):
    for idy,val in enumerate(l):
        total_exp_react[idx][idy] = val.replace("+", "")

total_exp_react
# Out:
# [['cgpa', 'project'],
#  [],
#  ['university', '2', '2'],
#  ['visakhapatnam'],
#  ['3'],
#  ['1'],
#  ['3'],
#  ['2'],
#  ['3'],
#  ['28', '28', 'percentage'],
#  ['2'],
#  ['32', '1', '32'],
#  ['32', '1', '32'],
#  ['9', '35'],
#  ['31'],
#  ['3'],
#  [],
#  ['2'],
#  ['2'],
#  [],
#  ['1', '1', 'boarduniversity'],
#  ['1'],
#  ['2'],
#  ['32']]

# %%
# Iterate through the list and replace '+' with ''
for idx, l in enumerate(total_exp_react):
    for idy, val in enumerate(l):
        # Check if the value is a number and contains a '+'
        if val.isdigit() and '+' in val:
            # Replace '+' with ''
            total_exp_react[idx][idy] = val.replace("+", "")
        # Check if the value is a number and does not contain a decimal
        if val.isdigit() and '.' not in val:
            # Add a decimal after the first integer
            total_exp_react[idx][idy] = val[:1] + '.' + val[1:]

# %%
# Convert the experience values to float and handle non-convertible values
def convert_to_float(exp_list):
  """
  Converts a list of experience values to float and drops non-convertible values.
  """
  float_exp = []
  for exp in exp_list:
    try:
      float_exp.append(float(exp))
    except ValueError:
      pass  # Ignore non-convertible values
  return float_exp

# Apply the function to the experience list
total_exp_react = [convert_to_float(exp_list) for exp_list in total_exp_react]
total_exp_react
# Out:
# [[],
#  [],
#  [2.0, 2.0],
#  [],
#  [3.0],
#  [1.0],
#  [3.0],
#  [2.0],
#  [3.0],
#  [2.8, 2.8],
#  [2.0],
#  [3.2, 1.0, 3.2],
#  [3.2, 1.0, 3.2],
#  [9.0, 3.5],
#  [3.1],
#  [3.0],
#  [],
#  [2.0],
#  [2.0],
#  [],
#  [1.0, 1.0],
#  [1.0],
#  [2.0],
#  [3.2]]

# %%
import numpy as np
# Flatten the list of lists
flat_list = [item for sublist in total_exp_react for item in sublist]

# Convert the strings to numbers
numeric_list = [float(x) for x in flat_list] # Changed int to float

# Calculate the average
if numeric_list:
  average_years = np.mean(numeric_list)
  print("Average years of experience:", average_years)
else:
  print("No numeric values found in the list.")
# Out:
# Average years of experience: 2.562962962962963

# %% [markdown]
# ### **EXPERIENCE OF SQL**

# %%
#SQL
total_exp_SQL = []
single_exp = []
for j in range(len(SQL_resume)): # Use len(SQL_resume) to get the number of rows
    nltk_tokens = nltk.word_tokenize(SQL_resume.Resume.iloc[j]) # Access the Resume value using .iloc[j]
    bi_list = list(nltk.bigrams(nltk_tokens))
    single_exp = []
    for i in bi_list:
        if i[1].rstrip('s') == 'year':
#             print(i[0])
            single_exp.append(i[0])
    total_exp_SQL.append(single_exp)
total_exp_SQL,len(total_exp_SQL)
# Out:
# ([['24'],
#   ['4', '3'],
#   ['211', 'cgpa'],
#   ['28'],
#   ['26'],
#   ['3'],
#   ['26'],
#   ['25', '1'],
#   ['23'],
#   ['210'],
#   ['25'],
#   ['35', '1', 'feb20201'],
#   ['32'],
#   []],
#  14)

# %%
# Iterate through the list and replace '+' with ''
for idx, l in enumerate(total_exp_SQL):
    for idy, val in enumerate(l):
        # Check if the value is a number and contains a '+'
        if val.isdigit() and '+' in val:
            # Replace '+' with ''
            total_exp_SQL[idx][idy] = val.replace("+", "")
        # Check if the value is a number and does not contain a decimal
        if val.isdigit() and '.' not in val:
            # Add a decimal after the first integer
            total_exp_SQL[idx][idy] = val[:1] + '.' + val[1:]

# %%
# Convert the experience values to float and handle non-convertible values
def convert_to_float(exp_list):
  """
  Converts a list of experience values to float and drops non-convertible values.
  """
  float_exp = []
  for exp in exp_list:
    try:
      float_exp.append(float(exp))
    except ValueError:
      pass  # Ignore non-convertible values
  return float_exp

# Apply the function to the experience list
total_exp_SQL = [convert_to_float(exp_list) for exp_list in total_exp_SQL]
total_exp_SQL
# Out:
# [[2.4],
#  [4.0, 3.0],
#  [2.11],
#  [2.8],
#  [2.6],
#  [3.0],
#  [2.6],
#  [2.5, 1.0],
#  [2.3],
#  [2.1],
#  [2.5],
#  [3.5, 1.0],
#  [3.2],
#  []]

# %%
# Flatten the list of lists
flat_list = [item for sublist in total_exp_SQL for item in sublist]

# Convert the strings to numbers
numeric_list = [float(x) for x in flat_list] # Changed int to float

# Calculate the average
if numeric_list:
  average_years = np.mean(numeric_list)
  print("Average years of experience:", average_years)
else:
  print("No numeric values found in the list.")
# Out:
# Average years of experience: 2.538125

# %% [markdown]
# ### **EXPERIENCE OF WORKDAY**

# %%
#WORKDAY
total_exp_Workday = []
single_exp = []
for j in range(len(Workday_resume)): # Use len(Workday_resume) to get the number of rows in the DataFrame
    nltk_tokens = nltk.word_tokenize(Workday_resume.Resume.iloc[j]) # Access the Resume using .iloc[] for position-based indexing
    bi_list = list(nltk.bigrams(nltk_tokens))
    single_exp = []
    for i in bi_list:
        if i[1].rstrip('s') == 'year':
#             print(i[0])
            single_exp.append(i[0])
    total_exp_Workday.append(single_exp)
del total_exp_Workday[2][0]
del total_exp_Workday[15][0]
del total_exp_Workday[6][2]
total_exp_Workday,len(total_exp_Workday)
# Out:
# ([['51', '36'],
#   ['3'],
#   [],
#   ['52', '38'],
#   [],
#   ['3', '2'],
#   ['57', '310'],
#   ['3', 'degreeexams', 'date', 'deptt', 'deptt', 'deptt'],
#   ['6', '35'],
#   ['5', '3'],
#   ['5', '3'],
#   ['3'],
#   ['33'],
#   ['5', '3'],
#   ['5', '3'],
#   ['4'],
#   ['4', '4'],
#   ['4', '4', '3'],
#   ['6'],
#   ['53', '3'],
#   ['42']],
#  21)

# %%
# Iterate through the list and replace '+' with ''
for idx, l in enumerate(total_exp_Workday):
    for idy, val in enumerate(l):
        # Check if the value is a number and contains a '+'
        if val.isdigit() and '+' in val:
            # Replace '+' with ''
            total_exp_Workday[idx][idy] = val.replace("+", "")
        # Check if the value is a number and does not contain a decimal
        if val.isdigit() and '.' not in val:
            # Add a decimal after the first integer
            total_exp_Workday[idx][idy] = val[:1] + '.' + val[1:]

# %%
# Convert the experience values to float and handle non-convertible values
def convert_to_float(exp_list):
  """
  Converts a list of experience values to float and drops non-convertible values.
  """
  float_exp = []
  for exp in exp_list:
    try:
      float_exp.append(float(exp))
    except ValueError:
      pass  # Ignore non-convertible values
  return float_exp

# Apply the function to the experience list
total_exp_Workday = [convert_to_float(exp_list) for exp_list in total_exp_Workday]
total_exp_Workday
# Out:
# [[5.1, 3.6],
#  [3.0],
#  [],
#  [5.2, 3.8],
#  [],
#  [3.0, 2.0],
#  [5.7, 3.1],
#  [3.0],
#  [6.0, 3.5],
#  [5.0, 3.0],
#  [5.0, 3.0],
#  [3.0],
#  [3.3],
#  [5.0, 3.0],
#  [5.0, 3.0],
#  [4.0],
#  [4.0, 4.0],
#  [4.0, 4.0, 3.0],
#  [6.0],
#  [5.3, 3.0],
#  [4.2]]

# %%
# Flatten the list of lists
flat_list = [item for sublist in total_exp_Workday for item in sublist]

# Convert the strings to numbers
numeric_list = [float(x) for x in flat_list] # Changed int to float

# Calculate the average
if numeric_list:
  average_years = np.mean(numeric_list)
  print("Average years of experience:", average_years)
else:
  print("No numeric values found in the list.")
# Out:
# Average years of experience: 3.9625

# %%
resume_data.head()
# Out:
#                                               Resume        Type
# 0  anubhav kumar singh core competency scripting ...  PeopleSoft
# 1  g ananda rayudu httpswwwlinkedincominanandguda...  PeopleSoft
# 2  peoplesoft database administrator gangareddy p...  PeopleSoft
# 3  classification internal classification interna...  PeopleSoft
# 4  priyanka ramadoss 6146 mountpleasant coonoor n...  PeopleSoft

# %% [markdown]
# ### **REMOVING ALL THE NAMES**

# %%
# Open and read the file
with open('names.txt', 'r') as file:
    names_df1 = file.read()

# %%
# Open and read the file
with open('last_names.txt', 'r') as file:
    names_df2 = file.read()

# %%
# Create DataFrames from the lists
names_df1 = pd.DataFrame(names_df1.splitlines(), columns=['First Name']) # Create a DataFrame with a 'First Name' column
names_df2 = pd.DataFrame(names_df2.splitlines(), columns=['Last Name']) # Create a DataFrame with a 'Last Name' column

# %%
names_df = pd.concat([names_df1, names_df2], ignore_index=True)

# %%
# Open and read the file, split into lines based on newline character
with open('names.txt', 'r') as file:
    names_list = file.read().splitlines()

# Convert the list of names into a set for faster lookups (lowercase for case-insensitivity)
indian_names = set(name.strip().lower() for name in names_list)

# %%
# Log the resumes that lose all content
missing_resumes = []

# Function to safely remove names
def safe_remove_names_from_resume(resume_text, names_set, max_words=3, threshold=0.5):
    original_word_count = len(resume_text.split())

    # Limit name removal to the first `max_words`
    cleaned_text = remove_names_from_resume_limited(resume_text, names_set, max_words)

    # If too much content is removed, log the resume and return the original text
    cleaned_word_count = len(cleaned_text.split())

    if cleaned_word_count < original_word_count * threshold:
        missing_resumes.append(resume_text)  # Log missing resume
        return resume_text  # Return the original text to avoid losing data

    return cleaned_text

# %%
# Same function as before to remove names from the first few words
def remove_names_from_resume_limited(resume_text, names_set, max_words=3):
    # Split the resume into words
    words = resume_text.split()
    result_words = []

    # Process only the first few words (e.g., first 3 words)
    for i, word in enumerate(words):
        if i >= max_words:
            result_words.extend(words[i:])  # Include remaining words
            break
        # Add word only if it's not in the names set
        if word.lower() not in names_set:
            result_words.append(word)

    return " ".join(result_words)

# %%
resumes = resume_data['Resume']

# Process each resume and remove names
cleaned_resumes = []
for resume in resumes:
    cleaned_resume = safe_remove_names_from_resume(resume, indian_names)
    cleaned_resumes.append(cleaned_resume)

# %%
# Log the missing entries
print(f"Total missing entries: {len(missing_resumes)}")
if missing_resumes:
    print(f"Missing Resumes: {missing_resumes}")
# Out:
# Total missing entries: 0

# %%
resume_data['Cleaned_Resume'] = cleaned_resumes

# %%
resume_data.head(5)
# Out:
#                                               Resume        Type  \
# 0  anubhav kumar singh core competency scripting ...  PeopleSoft
# 1  g ananda rayudu httpswwwlinkedincominanandguda...  PeopleSoft
# 2  peoplesoft database administrator gangareddy p...  PeopleSoft
# 3  classification internal classification interna...  PeopleSoft
# 4  priyanka ramadoss 6146 mountpleasant coonoor n...  PeopleSoft
#
#                                       Cleaned_Resume
# 0  singh core competency scripting shell scriptin...
# 1  g rayudu httpswwwlinkedincominanandgudapati g ...
# 2  peoplesoft database administrator gangareddy p...
# 3  classification internal classification interna...
# 4  ramadoss 6146 mountpleasant coonoor nilgiris 6...

# %%
resume_data = resume_data.drop('Resume', axis=1)

# %% [markdown]
# ### **REMOVING UNNECESSARY WORDS**

# %%
def remove_experience_using(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in ["summary", "professional", "objective", 'singh', 'having',
                                    'career', 'education', 'jan', 'feb', 'march', 'aug', 'oct', 'nov']]
    return ' '.join(filtered_words)

# Apply the function to the 'Filtered_Resume' column
resume_data['Cleaned_Resume'] = resume_data['Cleaned_Resume'].apply(remove_experience_using)

# %% [markdown]
# ### **REMOVING PHONE NUMBERS**

# %%
import re

def remove_phone_numbers(text):
    # Regular expression pattern to match 10-digit phone numbers
    phone_pattern = r'\b\d{10}\b'

    # Check if text is a string
    if isinstance(text, str):
        # Substitute phone numbers with an empty string
        cleaned_text = re.sub(phone_pattern, '', text)
        return cleaned_text
    else:
        return text

# Apply the function to each element in the 'Cleaned_Resume' column
resume_data['Cleaned_Resume'] = resume_data['Cleaned_Resume'].apply(remove_phone_numbers)

# %% [markdown]
# ### **CLEANED RESUME**

# %%
# Print the cleaned resumes
for i, resume in enumerate(resume_data['Cleaned_Resume']):
    print(f"Cleaned Resume {i+1}: {resume}\n")
# Out:
# Cleaned Resume 1: core competency scripting shell scripting application peoplesoft hcm financials operating linux window webapp server weblogic tuxedo rdbms oracle repository github core competency scripting shell scripting application peoplesoft hcm financials operating linux window webapp server weblogic tuxedo rdbms oracle repository github work globally competitive environment challenging assignment shall yield twin benefit job satisfaction steadypaced growth 062019 current hcl current role admin offshore skill shell scripting linux peoplesoft administration github managing peoplesoft hcm peoplesoft fscm production environment support environment installed linux window o involved day day activity project migration database refresh admin change tax update troubleshooting various server like application server web server process scheduler server applying tuxedo weblogic middleware cpu patch various application working shell scripting used integration method exchange file external installation troubleshooting 2tier setup requirement reviewing vulnerability reported security team renewal ssl weblogic vulnerability remediation vulnerability report rmis team worked pum peoplesoft update manager installation dpk working knowledge ansible docker developing new shell script troubleshooting shell script failure 072017 062019 techmahindra roleproject application support automationdevops tool peoplesoft admin skill shell scripting linux peoplesoft administration jenkins ansible project 1 people tool 855 upgrade hcm 92 application upgrade project 2 migration application ntt cloud onpremises aws cloud worked shell scripting various application requirement working ansible jenkins automated startstop various activity application basic knowledge docker applying ssl certificate new released application worked elastic search configuration peoplesoft gained knowledge aws resource strong understanding unix architecturecommand trouble shooting unixlinux platform efficient configuration management deployment tool like ansible good job scheduling crontab ibm tivoli workload scheduler tws good knowledge automation shell scripting continuous integration management jenkins installing configuring jenkins responsible writing ansible playbook perform various task managed administration task installation configuration application troubleshooting performance related issue applying tuxedo weblogic cpu patch various application working vulnerability reported security team reviewing platform certification information product platform database server web application server browser product peopletools 855 server migration aws amazon web service installation peoplesoft server component application server process scheduler server tuxedo web logic server new release peopletools unixlinux server applying latest patch peopletools installing configuring change assistant various upgrade pass creating running peopletools upgrade job peopletools 855 upgrade setting performance monitor creating new app web process scheduler domain post upgrade new linux severs troubleshooting common domain boot problem identifying configuring source target database ca hcm 92 application upgrade working hcm pum image creating change package pum applying sourcetarget database requirement creating application upgrade job change assistant 092015 072017 srdt pvt srm group roleproject peoplesoft application database admin skill peoplesoft administration weblogic tuxedo app designer pum peopletools upgrade peoplesoft campus application upgrade maintaining 7 production environment 21 supporting environment installed window server 2008 r2 oracle 11g posse knowledge peoplesoft architecture administering peoplesoft server component application server process scheduler server tuxedo web logic server pia peoplesoft internet architecture integration broker report node application issue technical issue peoplesoft skill migration production support p application exposure applying peoplesoft bundle upd ...
#
# Cleaned Resume 2: g rayudu httpswwwlinkedincominanandgudapati g ananda rayudu httpswwwlinkedincominanandgudapati profile 7 year implementing upgrading supporting peoplesoft database administration including human capital management hcm financials campus solution portal ihub expertise installation configuration setup security management peoplesoft internet architecture pia environment indepth analysis planning development implementation stage including load testing quality assurance tuning gained extensive exposure deploying peoplesoft environment experienced troubleshooting peoplesoft component skilled capability analyse interpret unique problem combination training logical thinking right solution core competency peoplesoft implementation troubleshooting peoplesoft performance issue project data migration installation configuration peoplesoft component pum dpk install configure upgrade people tool expertise applying patch update change assistant tool including tax update elastic search install configure peoplesoft refreshes cloning integration broker setup configuration maintaining workflow peoplesoft user monitoring log file search bottleneck server peoplesoft security resetting password lockingunlocking user profile installing middle tier component oracle quarterly security patch configuring change assistant apply fix patch set peoplesoft cloud infrastructureiaas awsec2 cloud managerlift shift application cloud ǁ work organization idc technology sol pvt project 1 multiple client texas department transportationtxdot duration 2019 till date role peoplesoft dba environment people tool 856 hrms 92 fscm 92 tuxedo 12220 weblogic 1223 oracle 12c responsibility performing project migration phire performing oracle security patchingjava wls installed middle tier component tuxedo weblogic jdk java performing peoplesoft database refresh troubleshooting application server process scheduler server report posting performance issue resolved developer issue like resetting password lockingunlocking user examining clearing cache server like application server monthly maintenance process prepared maintained documentation non prod prod refresh organization safalta infotech pvt 2013 2019 project 1 multiple client university texas ut papa jones duration 2016 2019 role peoplesoft dba environment people tool 855 856 hrms 92 fscm 92 campus solution 90 portal solution 91 tuxedo 11220 12220 weblogic 1123 1223 oracle11g and12c responsibility implemented complete peoplesoft life cycle scratch production golive activity executing peoplesoft internet architecture pia demo development support test production instance psadmin utility administer create app server process scheduler server webserver domain installed middle tier component tuxedo weblogic jdk java performed peoplesoft database refresh peoplesoft cloning activity performing project migration application designer maintaining workflow peoplesoft user monitoring log file search bottleneck server troubleshooting application server process scheduler server report posting performance issue resolved developer issue like resetting password lockingunlocking user provided resolution client analysed production issue examining clearing cache server like application server monthly maintenance process setup integration broker defining gateway creating configuring application node prepared maintained documentation entire configuration running audit report review sys ddd audit data inconsistency performed data migration performing production performed server load balancing webserver application tier hand setting pumdpk image creating change package application fix bug configured change assistant download update fix apply target environment install configure elastic search performed executed oracle cpu quarterly security patch nprod prod environment perfumed instance verification test patching database refresh cloning activity performed people tool upgrade release 855 856 install configure dpk image extracting peo ...
#
# Cleaned Resume 3: peoplesoft database administrator gangareddy work challenging environment best utilizing talent keeping abreast latest technical advancement field peoplesoft application dba derive utmost job satisfaction knowledge field successful oracle peoplesoft application dba activity 4 year peoplesoft application admindba creating configuring application server domain created multiple server domain separate host access database effective strategy performance tuning application server administration ensured availability implementing failover spreading multiple domain multiple host peoplesoft server administration expertise installation configuration setup management database peoplesoft internet architecture pia environment related processing object extensive applying tax update patch fix bundle maintenance pack experienced peoplesoft application administrator including performance problem sqr report app engine tuning sql index creation migration change management extensive refreshing development qa production database migrating change qa production evaluating required patch applying peoplesoft timely basis report management monitoring batch environment peoplesoft server administration expertise installation configuration setup management database peoplesoft internet architecture pia environment related processing object monitoring scheduling job security administration creating managing batch environment taking scheduled backup backup strategy rman configured maintaining rman backup oracle sql server database experienced taking regular offline online logical backup backup like logical backup exp imp datapump successfully installed configured oracle s peoplesoft environment involved configuration ssl certificate weblogic 103 12c successfully installed applied pum peoplesoft update manager technical skill erp package peoplesoft hrmsfscmcrmcshcmportal 90 9192 people tool version peopletools 848850852853854855857 application server bea tuxedo 81oracle tuxedo 10312c web server bea weblogic 81oracle weblogic 10312c database oracle 10gr2 11gr2 mssql server 2008r220122014 operating rhel as4 oel 55 oel 6 window 20032008r2 working emergtech business solution india pvt 2017 till date client amerit fleet solution duration sep 2019till database mssql server 20122014 role peoplesoft administratordba environment peoplesoft hcm fscm crm elm c portal 9091 pt v852853854 oracle 10g11gr2 12cr1 rhel window 2008 r2 server project kc managed service responsibility successfully installed configured web logic server application server component database server window operating successfully installed configured oracle s peoplesoft environment involved installation application database environment involved configuration ssl certificate weblogic 103 working daily production development administration activity perform proactive monitoring involved supporting team member various project successfully applied peoplesoft update managerpum handled application management task like applying patch fix cloning production server testing purpose like applying patch bundle installed peoplesoft database application nt unix operating installed configured oracle database updated database applying updatesfixespatches backup timely basis kept record updatesfixespatches configured application server web server batch process scheduler server configured window development client connect 2tier 3tier database development administration purpose client db duration 2017aug 2019 database db2 role peoplesoft administratordba environment peoplesoft fscm pt v8 854857 db2 rhel window 2008 r2 server project db managed service responsibility configured application server webservers batch process scheduler server extensively used psadmin utility administer create delete application server process scheduler server monitored server client queue status tuxedo domain changed psappsrvcfgpsprcscfg configuration file performance tuning specific environment checked cleared application ser ...
#
# Cleaned Resume 4: classification internal classification internal murali 6 year working peoplesoft administration performing various infrastructure related activity peoplesoft environment installed configured peoplesoft 909192 web server application server database server process scheduler server window unix linux platform creating domain web server application server process scheduler server applied patch manually applied maintenance pack change assistant tool dpks installation applying tax update fix pum migrating project environment environment application designer capi stat tool performed single sign ssoimplementation running compare report pre post migration setting client workstation developer tester involved configuration integration broker setting module sending message involved 247 production support client involved running audit report dddaudit sysaudit integrity check configuration setup ren server configured maintained report node setting checked clear cache server involved troubleshooting server like application server web server process scheduler server worked peopletools upgrade pt852 pt855 855 857 installing configuring elastic search 612 profile date organization role 22nd mar 2021 25th 2021 l n t infotech peoplesoft administrator client sembcorp brazil description project involved active production support field hrms 92 additionally involved maintenance enhancement responsibility installation setup people soft hcm elm 92 oracle creating database user assigning role privilege user maintaining various people soft instance debugging resolving issue related application serverweb serverprocess scheduler weeklymonthly database maintains performed people tool upgrade 85514 85705 performing post refresh activity date organization role 9th 2018 19th mar 2021 regency technology peoplesoft administrator client wipro ind platform people tool 856 people soft hcm 92 description project involved active production support field hrms 92 additionally involved maintenance enhancement responsibility installation setup people soft hcm 92 oracle creating database user assigning role privilege user maintaining various people soft instance debugging resolving issue related application serverweb serverprocess scheduler weeklymonthly database maintains creating modifying data mover script migrating project capi applying patch setting peoplesoft reporting environment reporting interacting client various production related issue applying tax update pum performing post refresh activity date organization role 9th 2015 30th 2017 dxc technology known csc peoplesoft administrator project title people soft hcm production support enhancement client asg usa platform people tool 852854 people soft hcm 9092 db2 aix 51 description project involved active production support field hrms 90 additionally involved maintenance enhancement responsibility installation setup people soft hcm 9091 db2 creating database user assigning role privilege user maintaining various people soft instance debugging resolving issue related application serverweb serverprocess scheduler weeklymonthly database maintains creating modifying data mover script migrating project statcapi applying patch setting peoplesoft reporting environment reporting interacting client various production related issue applying tax update pum performing post refresh activity technology operating window platform linux erp tool peoplesoft hrms 90 peopletools 847848 850 852 putty sql toad compare rdbms oracle 10g11g scheduling tool autosys version control tool capi stat language c c sql personal date birth nationality indian date place hyderabad
#
# Cleaned Resume 5: ramadoss 6146 mountpleasant coonoor nilgiris 643102 excel software working learning challenging environment utilize skill knowledge diligence dedication ensure maximum contribution growth organization work profile adept 411 year september 2016 present peoplesoft admin accenture peoplesoft administrator september 2016present peoplesoft administration finance application proficient creating configuring peoplesoft component like web server application server process scheduler active monitoring non production database application knowledgeable peoplesoft migration application designer data mover taking compare report moving code dev test production environment usage hp ppm tool perform peoplesoft migration compare report generation life cycle installation peoplesoft environment pre post database refresh activity change package creation applying bug fix change assistant peoplesoft db proficient administration peoplesoft server component like application server process scheduler webserver peoplesoft internet architecture good knowledge basic peoplesoft configuration like integration broker setup pum setup ssl file attachment trouble shooting hand peoplesoft security level activity like creating user profile assigning role permission list sso login creation user renewing web certificate performing sox check migration production release monthly basis conversant usage controlm v9 tool used creating scheduling job experienced setting batch profile setup server level running controlm job testing production environment peoplesoft batch monitoring implementation worked change assistant applying people tool patch creating change packagees target database ca online working unix window worked delphix virtual database non production database refreshes carrying maintenance activity server good communication leadership ability problem solving skill vmware itbm application support associate configuring maintaining infrastructure itbm application window o worked apache tomcat 7039 7052 vmware itbm 80 82 version window server ssl configuration complete batch setup window envrironment handling production non production database itbm tool technology operating window 200720082012 server r2 solaris server linux red hat version apache tomcat 7039 7052 aws service tool compute storage network database monitoring identity access management project management tool odyssey dashboard odyssey jira service transporter database sql developer peoplesoft people tool 85506 85522 857 peoplesoft application fscm 922 version reporting p tool application designer data mover delphix virtual database configuration manager change assistant sqr nvision controlm scheduler hp ppm sql developer centrify putty configuration manager key achievement infrastructure support production environment provide contingency plan analyze technical functional aspect supported application troubleshoot problem based requirement detailed analysis reporting project activity organization accenture solution pvt client credit suisse client description credit suisse group ag global wealth manager investment bank financial service company providing service investment banking provate banking asset management sahred service responsibility environment administration management financial application location bangalore duration september 2016 present course schoolcollege boarduniversity year passing percentage ece sri krishna college engineering technology coimbatore anna university 2016 86 hsc bharathi vidya bhavan erode state board technical 2012 9608 school topper sslc st joseph convent anglo indian girl higher secondary school nilgiris angloindian 2010 938 district personal profile ootacamund ooty tamil nadu district place birth tamil native english advanced comprehension oral kannada intermediate oral hindi intermediate sanskrit intermediate language reading book yoga gardening surfing hobby
#
# Cleaned Resume 6: sirazuddin m bangalore india sirazuddin m bangalore india profile overall 68 year peoplesoft administrator installed peopletools 855 scratch including product peopletools 851 85408 85507application 90 92 hrmsfscm deterministic approach problem solving troubleshooting proficient integration broker upgraded fscm hcm application peopletools 85507 peopletools 85408 graduated btech electronics communication engg mvgr college engineering vizianagaramjntuk aggregate 6893 achieved 90 mark 12th standard scored 86 10th standard achievement awarded bravo 2015 q3 2016 q1 pat q2 2016 q1 2017 techahindra awarded associate month award innovator month 1 time awarded spot pat capgemini work capgemini may19 till production support 5 finance environment respective non production environment project project axa role consultant environment window server 2012 r2 cognizant technol ogy sol ut ion augus t 1 8 april19 voya financial insurance u client project deal support managing finance application project project voya financials role associate environment window server 2012 r2 tech mahindra limit ed july 1 4 augus t 18 peoplesoft 92 implemented hr fin application peoplesoft 92 implementation project includes 10 peoplesoft application interface thirdparty application interface live production peoplesoft 92 environment sdlc project project role environment cio common software engineer solaris window server 2008r2 responsibility provided administrative support peoplesoft tool version 851 854 85525 85610 application hrms 90 92 financialsscm 90 92 module window unix o creation index table application designer peoplesoft database setup troubleshooting issue daily peoplesoft admin activity configured peoplesoft application server process scheduler web server domain setup master scheduler installing oracle tuxedo weblogic java application disk fscm hcm oracle database unix window server scratch installed peopletools 855 hcm fscm demo database upgraded fscm application peopletools 855 peopletools 85408 applied patch 85507 fscm configured report node bouncing app web process scheduler clearing cache performed prerefresh post refresh activity database cloning activity recompilation cobol source code worked project migration application designer change assistant applied image 15 16 25 37 fscm 92 pum change assistant good handson application designer data mover change assistant aware pia peoplesoft internet architecture configuring integration broker report node creating udm file transfer interface monitoring deploying gnupg key certificate server installed configured elastic search tool used peopletools 85408 85610 85525 application designer data mover toad sqldeveloper microsoft sql management studio 2014 oracle 11g oracle 12c microsoft sql server 2014 filezilla winscp pcomm tws service silva training certification oracle cloud infrastructure architect associate oracle cloud infrastructure architect
#
# Cleaned Resume 7: peoplesoft administrator srinivask 10 year peoplesoft administrator ample peoplesoft installationsconfigurations security administration adept implementing supporting peoplesoft database administration dba including human resource management hrms financial f thorough knowledge administrating peoplesoft server component like peoplesoft application server process scheduler server tuxedo web logic server pia peoplesoft internet architecture application messaging integration broker sql server application issue technical issue installing administering peoplesoft software configuring workstation application server process scheduler tuxedo web server pia report repository report node peoplesoft application installed elastic search configured peoplesoft solid understanding peoplesoft technical architecture tool proficient performing administer patch update upgrade develop implement plan data migration installing configuring pum applied tax update pum aided maintenance peoplesoft pure internet architecture including web logic tuxedo report process server posse thorough knowledge peoplesoft architecture peoplesoft administration design implementing suite corporation specific need cobol installation troubleshooting compiling cobol issue performed integration broker setup module worked instance verification test data refresh production ensuring data integrity tool dddaudit sysaudit development phase helped create implement security server administration procedure sql oracle database developed functional technical specification performed administrative duty worked autosys scheduling process monthly maintenance activity like cleaning application web process scheduler server experienced people tool upgrade knowledge application upgrade experienced monitoring peoplesoft job tivoli job scheduling console tool creating new job scheduling job requirement troubleshooting issue training junior employee peoplesoft administration related task handled project migration security request work order sent ticketing performed refreshing source target database peoplesoft online offline cloning server adaptive cloud strategy based aws aws cloud platform feature includes ec2 vpc eb cloud watch load balancer iam s3 qualification bachelor technology cse jntu lenora college egg andhrapradesh year 2006 technical skill peoplesoft peoplesoft application 89 90 91 92 people tool version 848849851852853854855857858 application designer application engine people code data mover process scheduler peoplesoft reporting tool pum image sqr p query xml publisher weblogic tuxedo weblogic819210gr311gr2tuxedo 81911011gr2 122 database oracle 10g oracle 11g oracle 12c operating window xp20002003 2008 2016r2 unix linux work currently working peoplesoft admin tech mahindramahindra satyam june2012 till date worked peoplesoft dba hexaware technology june 2009 2012 project7 environment unix window 2016 server 64bit database 12c application level hrms 9235 tool version 85706 project nissan responsibility involved peopletools upgrade people tool 855 857 supporting hcm fscm application apps dba 247 basis strong peoplesoft pum server installation troubleshooting applying fix patch bundle peoplesoft fscm92 hrms92 peoplesoft pum applied security patch weblogic tuxedo oracle release cpu setup masterslave load balance pubsub service worked intensively performance tuning pia architecture based load testing scaling architecture support expected load created dedicated integration broker gateway message volume wa high easy maintenance installed elastic search configured peoplesoft deployment peoplesoft dpk applying peoplesoft release patch prp peoplesoft image applying webserver oracle weblogic patch experiencing applying application server oracle tuxedo patch migrating code change testing production environment redesigned configured high availability load balancing existing peoplesoft internet architecture build verification test check proper installation running process repor ...
#
# Cleaned Resume 8: peoplesoft admin varkala vikas total 42 year peoplesoft admin peoplesoft dba hope enhance skill set adding value business enable implementation solution aid company understanding anticipating need motivation client deliver time budget quality delivering value improving agility quality reliability 42 year peoplesoft implementation support people tool upgrade configuration migration maintenance administration application server domain process scheduler server web server domain pum elastic search involved various tool application upgrade driving infrastructure hardware upgrade disaster recovery activity configured http secure web server ssl administration monitor developing maintaining monitoring shell script oracle database administration 11gr2 12cr1 12cr2 health check peoplesoft environment peoplesoft database refreshes production development testing environment performance tuning application server web server window administration implemented peoplesoft internet architecture pia demo test development production instance extensively involved resolving performance issue peoplesoft installation peopletools 856857 hcm 92 weblogic 12cr2 tuxedo 12cr2 people book 856857 window 2012r2 depth peoplesoft update manager pum applying peopletools patch application bundle peopletools hrms 92 fscm 92 application depth integration broker setup secure socket layer ssl implementation peoplesoft proficiency creation configuration administration application server domain process scheduler domain web server domain reconfiguration application server domain process scheduler server domain web server domain project migration application designer data migration data mover generating precompare report post compare report various environment setting client work station developer tester resolving developer issue like resetting password locking unlocking user account maintain workflow peoplesoft user worked applying patch bundle tax update change assistant peoplesoft update manager pum installing configuring change assistant apply bundle taxupdates involved setup configuration integration broker financials hcm application maintaining integrity internal consistency database dddaudit sysaudit alteraudit report periodically clearing cache server application server domain web server domain process scheduler server regular basis monitor log file bottleneck status server maintaining troubleshooting various server like application server domain process scheduler domain web server domain regularly involved doing database cloning refreshing peoplesoft instance installing cobol software compilation tuning application server domain process scheduler domain web server domain depth peoplesoft database performance tuning data guard dr support database patching peoplesoft database refreshes rman good team player proven individual contributor area technical skill technology tool erp tool people tool 857856855854853change assistant integration broker application designer configuration manager peoplesoft update manager pum s data mover peoplesoft hrmsfscmcrm 909192 application server tuxedo 103612c r112c r2 web server weblogic10312c r112131221312214 operating window server 2012 r22008 r22003 oracle enterprise linux 55657 hpux 1131 database oracle 12cr112cr2 educational qualification bsc osmania university 2017 worked peoplesoft administrator peoplesoft dba progile infotech pvt july 2017 till date project achievement client hartford insurance group hartford ct project install configure production support peoplesoft application database environment people tool 857856855 hrms92 fscm92 oracle 12c tuxedo 12cr2 oracle weblogic 12cr2 window server 2012 r2 oracle enterprise linux 56 role peoplesoft adminpeoplesoft dba duration july 2017 till date role responsibility monitoring daytoday working build verification test check proper installation running peoplesoft component process report object migration different instance involving compare report building object in ...
#
# Cleaned Resume 9: akkala peoplesoft dba admin 7years peoplesoft admindba implementation supporting peoplesoft application like hcmfscm module oracle database supporting operating implementing peoplesoft internet architecturepia demodevtestproduction instance configuration application server domain process scheduler setup performed installation configuration maintained oracle 10g11g12c database unix linux nt server project migration data migration generating compare report various environment worked applying patch bundle tax update configuring change assistant apply bundle tax update maintaining integrity internal consistency database dddaudit sysaudit alteraudit report periodically experienced integration broker setup worked applying patch bundle tax update change assistant peoplesoft update manager pum people tool upgrade ib peoplesoft refreshes peoplesoft security experienced cobol compilation window linux load balancing application server domain process scheduler server domain installed people book configured web server access people book troubleshooting various server like application server web server process scheduler server involved regular backuprecovery oracle database including logical physical backup applying database patch working capacity planning table space applying database upgrading installing maintaining upgrading migrating patching oracle version 10g11g12c database refreshes linux admin rman configuration database security management user role profile taking hot cold backup resolving developer issue like resetting password supporting role database cloning managing size file table space adding data file table space multiplexing control file data pump technology tuning application server domain process scheduler domain web server domain key skils technology tool erp tool peopletools854853850changeassistant integrationbroker applicationdesignerconfiguration manager peoplesoft update manager pum data mover application peoplesoft hrmsfscmcrm 909192 application server tuxedo 10312c web server web logic 10312c operating window server 2012 r22008 r22003 red hat enterprise linux 56 oracle enterprise linux 5467 database oracle 10gr211gr212c educational qualification mcamasterof computer application sri venkateswara university tirupati 2012 75 andhra pradesh working peoplesoft database administrator infosys bangalore 2020 till date parent companygem source india working peoplesoft database administrator sify technology bangalore 2019 april 2020 worked peoplesoft database administrator wipro technology bangalore 2018 2019 worked peoplesoft administrator peoplesoft dba sonata software bangalore june 2016 august 2018 worked peoplesoft dba moonstone infotech pvtltd hyderabad 2013 2016 relevent 2020 till date project peoplesoft admin support client goldman sach duration 2020till date role peoplesoft database admin environment application version hrmsfscm 92 89 people tool version pt 856 pt 853 database oracle 12c supporting fscmhrms application peoplesoft dba 247 basis peoplesoft database administrator supporting fscmhrms environment maintained oracle 12c11g peoplesoft dba supporting hrmsfscm 92 89 environment maintained rhel 4 oracle 12c 11g peoplesoft internet architecture pia including unix file application server web server batch server migration peoplesoft project dev test prod instance analysis production issue raised client providing solution executing ddd audit sys audit alter audit generating compare report peopletools patch tool upgrade certificate peoplesoft refreshes ib pum setting report node checking posting status peoplesoft security disk space issue configuring monitoring process scheduler troubleshooting various issue related involved performance database application creating multiple domain instance troubleshooting tuxedo application server process scheduler web server database administration performance tuning support database requirement creating database user setting default temporary table space assign ...
#
# Cleaned Resume 10: peoplesoft adminpeoplesoft dba ganesh alladi total 64 year valid expertise 44 year peoplesoft admin peoplesoft dba hope enhance skill set adding value business enable implementation solution aid company understanding anticipating need motivation client deliver time budget quality delivering value improving agility quality reliability 44 year peoplesoft implementation support peopletools upgrade application upgrade configuration migration maintenance administration application server domain process scheduler server web server domain pum s involved various tool application upgrade extensively involved resolving performance issue configured http secure web server ssl administration monitor developing maintaining monitoring shell script oracle database administration 11gr2 12cr1 12cr2 health check peoplesoft environment peoplesoft database refreshes production development testing environment performance tuning application server web server linux hpux window administration implemented peoplesoft internet architecture pia demo test development production instance peoplesoft installation peopletools 856 hcm 92 weblogic 1213 tuxedo 12cr2 people book 856 hpux window 2012r2 peoplesoft installation peopletools 854 hcm 92 weblogic 1212 tuxedo 12c r1 people book 854 window 2012 r2 oracle enterprise linux 6 peoplesoft installation peopletools 853 fscm 92 weblogic 1036 tuxedo 103 people book 853 window 2008 r2 oracle enterprise linux 54 peoplesoft installation peopletools 850 hcm 91weblogic 103 tuxedo 103 oracle 10g r2 people book 850 window server 2003 oracle enterprise linux 5 depth peoplesoft update manager pum applying peopletools patch application bundle peopletools hrms 92 fscm 92 application depth integration broker setup secure socket layer ssl implementation peoplesoft proficiency creation configuration administration application server domain process scheduler domain web server domain reconfiguration application server domain process scheduler server domain web server domain project migration application designer quest stat tool data migration data mover generating precompare report post compare report various environment setting client work station developer tester resolving developer issue like resetting password locking unlocking user account maintain workflow peoplesoft user worked applying patch bundle tax update change assistant peoplesoft update manager pum installing configuring change assistant apply bundle taxupdates involved setup configuration integration broker financials hcm application maintaining integrity internal consistency database dddaudit sysaudit alteraudit report periodically clearing cache server application server domain web server domain process scheduler server regular basis monitor log file bottleneck status server maintaining troubleshooting various server like application server domain process scheduler domain web server domain regularly involved doing database cloning refreshing peoplesoft instance installing cobol software compilation tuning application server domain process scheduler domain web server domain depth peoplesoft database performance tuning data guard dr support database patching peoplesoft database refreshes rman good team player proven individual contributor area technical skill technology tool erp tool peopletools 855854853850change assistant integration broker application designer configuration manager peoplesoft update manager pum s data mover peoplesoft hrmsfscmcrm 909192 application server tuxedo 103612c r112c r2 web server web logic 10312c r11213 operating window server 2012 r22008 r22003 redhat enterprise linux 56 oracle enterprise linux 55657 hpux 1131 database oracle 10gr211gr212cr112cr2 m sql server 20082012 educational qualification btech jntu hyderabad 2012 worked peoplesoft administrator peoplesoft dba dxc technology july 2019 2021 worked peoplesoft administrator peoplesoft dba san information technology solution pvt sep 2016 july 2019 worked oracle dba ...
#
# Cleaned Resume 11: peoplesoft administration vivekanand sayana valid expertise 75 year peoplesoft hope enhance skill set adding value business enable implementation solution aid company understanding anticipating need motivation client deliver time budget quality delivering value improving agility quality reliability 75 year peoplesoft implementation support configuration migration maintenance administration application server domain process scheduler server web server domain peopletools upgrade application update pum s elastic search integration activity various peoplesoft financials hrms epm fscm environment extensively involved resolving performance issue driving infrastructure hardware upgrade disaster recovery activity health check peoplesoft environment peoplesoft database refreshes production development testing environment performance tuning application server web server performed 3 life cycle implementation peoplesoft implemented peoplesoft internet architecture pia demo test development production instance peoplesoft implementation peopletools 856 fscm 92 web logic 1221 tuxedo 1222 oracle 12c r2 oracle enterprise linux 7 window 2012 r2 peoplesoft installation peopletools 855 hcm 92 weblogic 1213 tuxedo 1213 people book 855 oracle enterprise linux 6 window 2012r2 peoplesoft installation peopletools 854 hcm 92 weblogic 1212 tuxedo 1210 people book 854 window 2012 r2 oracle enterprise linux 6 peoplesoft installation peopletools 853 fscm 92 weblogic 1036 tuxedo 103 people book 853 window 2008 r2 oracle enterprise linux 54 peoplesoft installation peopletools 850 hcm 91weblogic 103 tuxedo 103 oracle 10g r2 people book 850 window server 2003 oracle enterprise linux 5 depth peoplesoft update manager pum applying peopletools patch application bundle peopletools 853 854 hrms 92 fscm 92 application dpks deploy pum latest image dpks install middle tier app tier peopletools depth integration broker troubleshooting proficiency creation configuration administration application server domain process scheduler domain web server domain reconfiguration application server domain process scheduler server domain web server domain project migration application designer data migration data mover generating precompare report post compare report various environment setting client work station developer tester resolving developer issue like resetting password locking unlocking user account maintain workflow peoplesoft user worked applying patch bundle tax update change assistant peoplesoft update manager pum installing configuring change assistant apply bundle taxupdates involved setup configuration integration broker financials hcm application maintaining integrity internal consistency database dddaudit sysaudit alteraudit report periodically load balancing application server domain process scheduler server clearing cache server application server domain web server domain process scheduler server regular basis monitor log file bottleneck status server troubleshooting data mover installing peoplesoft maintaining troubleshooting various server like application server domain process scheduler domain web server domain tuning application server domain process scheduler domain web server domain strong communication collaboration team building interpersonal skill good team player proven individual contributor area technical skill technology tool erp tool people tool 856855854853850change assistant integration broker application designer configuration manager peoplesoft update manager pum s data mover application peoplesoft hrmsfscmcrm 909192 application server tuxedo 81103612c r112c r2 web server web logic 8110312c r11213 operating window server 2012 r22008 r22003 redhat enterprise linux 56 oracle enterprise linux 5567 database oracle 10gr211gr212cr112cr2 educational qualification mba hr marketing kbn college nagarjuna university vijayawada 2011 bsc bachelor science srr cvr college nagarjuna university vijayawada 2009 worked peoplesoft administrator ...
#
# Cleaned Resume 12: 04 year 08 month multiple peoplesoft upgrade implementation support project fscmhcm global client depth knowledge working peopletools application engine peoplecode application package file layout exceltoci psquery reporting sqrs bi publisher worked fscm upgrade includes vanilla compare retrofitting object sit uat live activity good upgrade implementation module good phase application development cycle design coding testing maintenance documentation worked creating custom report bi publisher sqr p query worked testing tool ptfpeoplesoft testing framework excellent capability explore learn understand newer business domain technology good communication skill software proficiency skill app package application engine people code sqr bip p query domain knowledge financial service retail healthcare development tool peoplesoft application designer data management data mover integration tool integration broker database oracle 11g 12c working currently working peoplesoft technical consultant december 2016 till date wipro technology educational qualification bca computer application guru gobind indraparastha university mtech software engineering bit pilani wipro wase program project tool upgrade 858 customer credit suisse domain financial service role hcm technical consultant period 2022 june 2021 description credit suisse group ag global investment bank financial service firm founded based switzerland responsibility analysis customizations es ms page fluid implementation converting es page fluid page like change home mailing address swiss payslip phone number email address emergency contact ethnic group converting ms page fluid data conversion bring attachment previous custom table new fluid delivered table batch catchup analysis check batch process require catchup golive worked cutover security document golive module es ms wa environment peoplesoft hcm 92 people tool 857858 project global offboarding automation customer credit suisse domain financial service role hcm technical consultant period july 2020 2021 description credit suisse group ag global investment bank financial service firm founded based switzerland responsibility created custom ms termination page manager submit resignation behalf direct reportees created checklist automation program complete checklist item configuration framework avoid manual check item created contract expiry reminder process send reminder short term employee contract getting expired 30157 2 day created bi report generate letter different region created custom stakeholder response page creation cutover document golive provided 247 support warranty period golive module es ms environment peoplesoft hcm 92 people tool 857 project end life ptf customer credit suisse domain financial service role financial technical consultant period april 2020 june 2020 description credit suisse group ag global investment bank financial service firm founded based switzerland responsibility retrofit object like app package app engine page peoplecode sql worked gl journal entry journal edit posting journal reversal journal worked peoplesoft testing framework regression testing gl module gl environment peoplesoft fscm 92 people tool 856 project lease administration customer credit suisse domain financial service role financial technical consultant period january 2020 april 2020 description credit suisse group ag global investment bank financial service firm founded based switzerland responsibility created feed process load lease file received external source worked creationmanaging financial operating lease ran lease process like straightline process depreciation calculate accounting entry depreciation close validated data dist_ln record worked amendment lease module lm environment peoplesoft fscm 91 92 people tool 851856 project labcorp 92 upgrade customer laboratory corporation america holding domain healthcare role financial technical consultant period december 2018 november 2019 description laboratory  ...
#
# ...
#
# Cleaned Resume 75: workday hcm consultant seeking suitable position workday hcm techno functional consultant reputed organization help utilize skill grow individual deliver organization growth 4 year serving notice highlight workday integration studio core hcm recruiting benefit leave absence training core financials integration workday studio strong eib inbound outbound report calculated field custom object business process dashboard ccwpicof calc field birt worked implementation configuration security business process achievement successfully completed 2 major project implementation kt new hire provide training internally technical skill workday hcm core hcm recruiting lm report writer eib calc field payment connector workday studio business process security dt benefit talent core connector picof document transformation birt people code app engine cixml xslt work working workday consultant wipro technology 2018 till worked software engineer infosys 2017 july 2018 workday consultant wipro 2018 till date 4 year erp including 3 year workday hcm completed workday integration support previous project excellent functional skill hcm module like core hcm leave absence recruiting setup expertise configuring business process various business process adding step condition rule involved project implementation testing managing business troubleshooting issue implementation post implementation support involved end end implementation configured various business process related leave absence condition rule business process good knowledge ion creating leave family leave type absence condition rule absence hand inbound outbound integration connector workday studio birt tool developed maintained customreport type like advanced matrix composite report writer expertise payroll integration wd adp p nga picof peci connector participate activity workday project working customer alignment session discovery meeting touchpoint meeting customer configuration testing production support familiar ticketing tool like service salesforce hplm incident cr expertise building eib enterprise interface builder integration wd sending data good knowledge etvxtt function dt sending data wd payroll hand workday security functional area security police domain expertise workday leave absence recruiting module configuring befit 401 plan configured business process leave absence recuring core hcm condition rule step created complex integration studio data syncope integration wd different inboundoutbound integration eib core connector report writing creating workday calculated field custom report matrix composite advanced birt tool monitor workday community portal new enhancement delivered new upgrade implement required enhancement business requirement identifying updated change excellent analytical problem solving communication interpersonal skill ability interact individual level consistently meet goal target date involved workday update testing integration supporting hrit team based request motivated team player willing accept exciting challenge sound industry involved transformation xml xslt presenting data different web service hand creating new security group updating security group various domain security police activating security policy identifying security business obj knowledge xml wdsoap web service wd rest web service workday consultant infosys 2017 2018 july responsibility created various eib outbound integration sending employee data wd external gdw worked development add additional functionality existing different picof integration workday studio code level configuration level developed various custom report compensation transfer created new matrix report sharing hris team creating isu issg report coordinate user uat phase testing change request developed studio integration merging multiple report sti lti workday studio created picof outbound integration generate multiple file like hire termination otp allowance party payroll sfdc case provided start proxy  ...
#
# Cleaned Resume 76: workday hcm fcm kumar s role workday consultant 6 year workday workday consultant involved workday hcmfcm security support enhancement project good understand various functional area hcm workday financial hcm core hcm absence time tracking recruiting benefit fcm procure pay payable business asset expense billing revenue technically proficient customizations enhancement various tool like report writer calculated field eib core connector dt workday studio good various core connector template like core connector worker picoff peci good working knowledge workday studio component like workdayin workdayout rest workdayout soap async mediation splitter aggregator mvel store csvtoxml workday studio good working knowledge technology xml xslt soap web service working peci payroll interface effective change creating custom object worked business process configuration security area based business requirement expertise report analyst advanced matrix composite report worked incident change request bau worked creating complex calculated field single instance lookup related value lookup date field custom report workday hcm worked eib inbound load data file workday web service cost center otp transfer change emergency contact information work configuring business process security configuration developing report working creating custom object custom field requirement good working security configuration creating isu creating security group good knowledge migrating report lower tenant sandbox production object transporter good problem solving communication skill currently working workday consultant itc infotech bengaluru oct2017 till date worked senior software engineer wipro july 2014 sep 2017 technical skill erp workday hcmfcm technical skill report writer calculated field eib picof workday studio core connector web service document transformationsql workday security configuration language xml xslt people code operating window linux project major project executed project 3 project workday support enhancement client itc infotech duration 2017 till date role srworkday consultant environment eib peci core connector web service dt studio role responsibility created new integration pull new hire information core connector worker document transformation connector integration xml output data source input created eib inbound integration loading data creating core connector integration peci payroll effective change interface template developed simple secure integration workday enterprise interface builder eib creating custom object custom field calculated field requirement inboundoutbound integration creation workday eib core connector developed custom report sending job anniversary alert worker manager initiation otp plan developed various custom report lookup audit report calculated field creating security group adding permission domain security policy involved creating inbound integration workday studio workday soap router component load compensation data workday involved loading data emergency contact cost center time payment bank account data enterprise interface buildereib web service like add updated org onetime payment modified xslt code crrequest adding new xslt code different info type hand etv xtt function document transformation handson migrating xslt code report lower tenet sandbox production object transporter understanding business requirement studying functional document project 2 project workday support enhancement client wipro duration jun 2016 sep 2017 role sr software engineer environment eib picof workday studio core connector web service dt role responsibility created various eib outbound integration sending customer contract data workday sale manger email group involved creating inbound integration workday studio workday soap router component load currency rate workday worked worktag configuration arrange posting rule set based worktag functionality worked custom validation maintain custom validation based busin ...
#
# Cleaned Resume 77: venkateswarlub workday consultant 53 year 3 year implementation maintaining workday hcm reporting integration life cycle implementation workday played key role integration developer hand technical workday hcm suite including custom reporting calculated field xslt workday studio workday security strong exposure phase workday implementation lifecycle requirement gathering analysis design development testing hand inbound outbound integration core connector workday studio birt eib business process security report writer expertise developing payroll interface picofpeci help workday studio document transformation meet client complex payroll requirement developed maintained various customreports type advanced matrix composite trending report writer tool help calc field business requirement configuring security various integration report security group track resolve user support issue current maintain good working relationship project team member internal customer core hcm absence time tracking recruiting external service vendor good workday core hcm recruiting benefit payroll time tracking module strong building workday studio inboundoutbound integration exposure edit tenant setup related configuration hcm security business process notification reporting analytics involved writing transformation code converting xml xslt different web service good knowledge defining security business process troubleshoot day day issue workday integration reporting issue fix root cause strong analytical problemsolving skill coupled outstanding communication presentation negotiation ability good migration tool business object transporter object environment environment technical skill technical skill workday skill workday hcm workday advanced report writer core connector picof document transformation workday studioeib workday web service workday security programming lang xml xslt xpath web technology soap xml web service operating window xpwindows710 work work working workday integration consultant genpact bangalore may2018 till date working software engineer osi consulting hyderabad mar2016 apr2018 completed bachelor technology b tech 2011 jntuh project project project 2 client aig support implementation workday hcm project description american international group known aig american multinational finance insurance corporation operation 80 country jurisdiction january 1 2019 aig company employed 49600 people company operates core business general insurance life retirement standalone technologyenabled subsidiarygeneral insurance includes commercial personal insurance u international field operation life retirement includes group retirement individual retirement life institutional marketsaig proud sponsor aig woman open golf new zealand rugby role workday integration consultant responsibility involved requirement gathering phase prepare business requirement specification document technical document responsible creating custom report advance matrix search trending nbox report involved building eib inbound outbound integration recruitment core hcm compensation payroll module worked building ccwweci integration extracting delta change worked picofpeci integration extracting payroll data change design build maintain integration type report eib core connector payroll connector studio provide day day support workday integration reporting issue good building studio inbound outbound integration complex integration utilized dt converting ccw picof output xml file text file good knowledge functional concept like business process handson migrating xslt code report lower tenet sandbox production involved configuring security role access restriction domain level bp level used sequence generator generating template validating inbound integration result project 1 client toll group support implementation workday hcm project description toll global logistics tgl division toll group provides integrated logistics solution asia pacific region division offer ...
#
# Cleaned Resume 78: v workday functional consultant expertise 42 year total workday functional consultant knowledge functional module workday core hcm supervisory organization delegation cost center location knowledge security implementing workday functional integration various module including hcm core compensation time tracking absence management payroll benefit performance management good knowledge security group role based user based job based experienced report writing custom report simple advanced matrix composite calculated field integration eib connector xml xslt workday web service organization structure custom object handson migrating xslt code report lower tenant sandbox production object transporter excellent object management skill workday like configuring supervisory organization matrix organization compensation salary based different grade allowance performance management time management business process hiring termination strong team player excellent interpersonal communication leadership skill ready independent challenge ha ability work team technical skill workday skill report studio workday business process security staffing report writer calculated field eib core connector web service language tool xml xslt studio document processing microsoft excel microsoft word microsoft powerpoint master business administration narayana engineering college 2017 80 work working workday consultant tech mahindra sep 2017 till date project 1 company tech mahindra project type workday support enhancement designation workday consultant role responsibility develop new integration eib core connector custom report based business requirement modification implementing multiple enhancement existing custom report calculated field xslt handson migrating report lower tenet sandbox production object transporter worked core connector template location worker document transformation worked integration user transfer ownership report schedule integration worked inbound outbound eib integration concept created various eib integration configure workday configurable security client business requirement created eib inbound integration loading employee personal information like emergency contact compensation onetime payment bank account cost center information monitor daily scheduler report error needed developed core connector document transformation integration change file csv format xml output strong knowledge working crchange request business requirement building moving change production involved performing mass loading data eib involved client update work status clarification day day support workday hcm integration reporting issue project 2 company tech mahindra project type peoplesoft support enhancement designation analyst role responsibility customized developed application engine loading bulk data external track resolve user support issue current maintain good working relationship project team member internal customer external service vendor designed technical document worked development interface conversion based design document modified designed configured built field record sub record setting key record assign table edits like prompt table involved online change delivered page component menu translate value customized developed application engine loading bulk data external developed modified people code implement specific business rule validation enable perform business process used file layout definition data legacy peoplesoft table managed monitored process scheduler issue scheduled interfacesprocesses ran resolved issue developedmodified various p query order help client daytoday activity worked reporting tool like p query xml publisher worked file layout application engine component interface file layout excel ci xml report declaration declare information furnished true best knowledge

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# **Label encoding 'Type' column.**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
resume_data["Type"] = le.fit_transform(resume_data["Type"])
resume_data.head(5)
# Out:
#    Type                                     Cleaned_Resume
# 0     0  core competency scripting shell scripting appl...
# 1     0  g rayudu httpswwwlinkedincominanandgudapati g ...
# 2     0  peoplesoft database administrator gangareddy w...
# 3     0  classification internal classification interna...
# 4     0  ramadoss 6146 mountpleasant coonoor nilgiris 6...
